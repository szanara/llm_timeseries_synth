# %%
pt_root = '/home/cz/'

# %%
path = pt_root+'mds3/COHERE/generated/mhad2'

# %%
path2save = pt_root+'mds3/COHERE/processed/mhad2'

# %%
pathfinal = pt_root+'mds3/COHERE/final/mhad2'

# %%
import os 
os.makedirs(path2save,exist_ok = True)
os.makedirs(pathfinal, exist_ok = True)

# %%
from utils import *

# %%
for fold in range(10):
    for cat in range(6):
        print(f'FOLD{fold}-CAT{cat}')
        correcting_size(path=path, path2save=path2save, cat = cat, fold=fold)
        zipping_all(path= path2save, cat =cat, fold=fold, path2save=pathfinal)
# Out:
# FOLD0-CAT0
# 100%|██████████| 30/30 [00:00<00:00, 15141.89it/s]
# (40, 3) before
# (50, 3) after
# saved
# (50, 3) before
# saved
# (54, 3) before
# (50, 3) after
# saved
# (50, 3) before
# saved
# (50, 3) before
# saved
# (43, 3) before
# (50, 3) after
# saved
# (50, 3) before
# saved
# (43, 3) before
# (50, 3) after
# saved
# (47, 3) before
# (50, 3) after
# saved
# (60, 3) before
# (50, 3) after
# saved
# (51, 3) before
# (50, 3) after
# saved
# (50, 3) before
# saved
# (51, 3) before
# (50, 3) after
# saved
# (38, 3) before
# (50, 3) after
# saved
# (50, 3) before
# saved
# (56, 3) before
# (50, 3) after
# saved
# (52, 3) before
# (50, 3) after
# saved
# (50, 3) before
# saved
# (51, 3) before
# (50, 3) after
# saved
# (61, 3) before
# (50, 3) after
# saved
# (39, 3) before
# (50, 3) after
# saved
# (50, 3) before
# saved
# (93, 3) before
# (50, 3) after
# saved
# (50, 3) before
# saved
# (51, 3) before
# (50, 3) after
# saved
# (50, 3) before
# saved
# (62, 3) before
# ...
